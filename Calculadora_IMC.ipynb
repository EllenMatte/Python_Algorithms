# %%
def calcular_imc(peso, altura):
    imc = peso / altura ** 2
    return imc

print("Calculadora de IMC")
print("-------------------")

peso = float(input('Informe o seu peso (em kg EX: 00.0): '))
altura = float(input('Informe sua altura (em metros EX: 0.00): '))

imc = calcular_imc(peso, altura)

print("-------------------")
print("Resultado:")
print(f'Peso: {peso} kg')
print(f'Altura: {altura} m')
print(f'Seu IMC é: {imc:.2f}')

if imc < 18.5:
    print("Classificação: Abaixo do peso")
elif imc < 25:
    print("Classificação: Peso normal")
elif imc < 30:
    print("Classificação: Sobrepeso")
elif imc < 35:
    print("Classificação: Obesidade grau 1")
elif imc < 40:
    print("Classificação: Obesidade grau 2")
else:
    print("Classificação: Obesidade grau 3 (mórbida)")
# Out:
# Calculadora de IMC
# -------------------
# Informe o seu peso (em kg EX: 00.0): 58.5
# Informe sua altura (em metros EX: 0.00): 1.74
# -------------------
# Resultado:
# Peso: 58.5 kg
# Altura: 1.74 m
# Seu IMC é: 19.32
# Classificação: Peso normal
